# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import load_model
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers, models

# Define the directory containing the dataset
dataset_dir = r'C:\Users\ketha\Downloads\major\bottle dataset'

# Function to get dataset partitions
def get_dataset_partitions_tf(ds, train_split=0.75, val_split=0.125, test_split=0.125, shuffle=True, shuffle_size=10000):
    assert (train_split + test_split + val_split) == 1

    ds_size = len(ds)

    if shuffle:
        ds = ds.shuffle(shuffle_size, seed=12)

    train_size = int(train_split * ds_size)
    val_size = int(val_split * ds_size)

    train_ds = ds.take(train_size)
    val_ds = ds.skip(train_size).take(val_size)
    test_ds = ds.skip(train_size + val_size)

    return train_ds, val_ds, test_ds

# Load the dataset using tf.keras.preprocessing.image_dataset_from_directory
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    dataset_dir,
    labels='inferred',
    label_mode='int',
    batch_size=32,
    image_size=(64, 64),  # Adjust the image size as needed
    validation_split=0.2,
    subset='training',
    seed=123
)

# Split the dataset into train, validation, and test sets
train_ds, val_ds, test_ds = get_dataset_partitions_tf(dataset)

# Check the lengths of the train, validation, and test sets
print("Number of training samples:", len(train_ds))
print("Number of validation samples:", len(val_ds))
print("Number of test samples:", len(test_ds))

# Cache, shuffle, and prefetch the training, validation, and test datasets
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds = val_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
test_ds = test_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# Define image resizing and rescaling pipeline
resize_and_rescale = tf.keras.Sequential([
    layers.experimental.preprocessing.Rescaling(1./255),
])

# Define data augmentation pipeline
data_augmentation = tf.keras.Sequential([
    layers.experimental.preprocessing.RandomFlip("horizontal"),
    layers.experimental.preprocessing.RandomRotation(0.2),
])

# Apply data augmentation to the training dataset
train_ds = train_ds.map(
    lambda x, y: (data_augmentation(x, training=True), y)
).prefetch(buffer_size=tf.data.AUTOTUNE)

# Model Architecture
BATCH_SIZE = 32
IMAGE_SIZE = 64
CHANNELS = 3

input_shape = (BATCH_SIZE, IMAGE_SIZE, IMAGE_SIZE, CHANNELS)
n_classes = 3

# Build the model
model = models.Sequential([
    resize_and_rescale,
    layers.Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=input_shape[1:]),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Flatten(),
    layers.Dense(64, activation='relu'),
    layers.Dense(n_classes, activation='softmax')
])

# Compile the model
model.compile(
    optimizer='adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']
)

model.build(input_shape=input_shape)
model.summary()
# Out:
# Found 486 files belonging to 3 classes.
# Using 389 files for training.
# Number of training samples: 9
# Number of validation samples: 1
# Number of test samples: 3
# Model: "sequential_30"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_28 (Sequential)  (32, 64, 64, 3)           0
#
#  conv2d_92 (Conv2D)          (32, 62, 62, 32)          896
#
#  max_pooling2d_91 (MaxPooli  (32, 31, 31, 32)          0
#  ng2D)
#
#  conv2d_93 (Conv2D)          (32, 29, 29, 64)          18496
#
#  max_pooling2d_92 (MaxPooli  (32, 14, 14, 64)          0
#  ng2D)
#
#  conv2d_94 (Conv2D)          (32, 12, 12, 64)          36928
#
#  max_pooling2d_93 (MaxPooli  (32, 6, 6, 64)            0
#  ng2D)
#
#  conv2d_95 (Conv2D)          (32, 4, 4, 64)            36928
#
#  max_pooling2d_94 (MaxPooli  (32, 2, 2, 64)            0
#  ng2D)
#
#  flatten_18 (Flatten)        (32, 256)                 0
#
#  dense_36 (Dense)            (32, 64)                  16448
#
#  dense_37 (Dense)            (32, 3)                   195
#
# =================================================================
# Total params: 109891 (429.26 KB)
# Trainable params: 109891 (429.26 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(
    train_ds,
    batch_size=BATCH_SIZE,
    validation_data=val_ds,
    verbose=1,
    epochs=50
)
# Out:
# Epoch 1/50
# WARNING:tensorflow:From C:\Users\ketha\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 9/9 [==============================] - 10s 444ms/step - loss: 0.8728 - accuracy: 0.5939 - val_loss: 0.8927 - val_accuracy: 0.8000
# Epoch 2/50
# 9/9 [==============================] - 1s 69ms/step - loss: 0.8301 - accuracy: 0.6437 - val_loss: 0.8424 - val_accuracy: 0.8000
# Epoch 3/50
# 9/9 [==============================] - 1s 72ms/step - loss: 0.8125 - accuracy: 0.6437 - val_loss: 0.8512 - val_accuracy: 0.8000
# Epoch 4/50
# 9/9 [==============================] - 1s 75ms/step - loss: 0.8071 - accuracy: 0.6437 - val_loss: 0.8921 - val_accuracy: 0.8000
# Epoch 5/50
# 9/9 [==============================] - 1s 73ms/step - loss: 0.8003 - accuracy: 0.6437 - val_loss: 1.0615 - val_accuracy: 0.8000
# Epoch 6/50
# 9/9 [==============================] - 1s 72ms/step - loss: 0.7745 - accuracy: 0.6437 - val_loss: 0.9032 - val_accuracy: 0.8000
# Epoch 7/50
# 9/9 [==============================] - 1s 80ms/step - loss: 0.8307 - accuracy: 0.6437 - val_loss: 0.9762 - val_accuracy: 0.8000
# Epoch 8/50
# 9/9 [==============================] - 1s 87ms/step - loss: 0.7768 - accuracy: 0.6437 - val_loss: 0.8727 - val_accuracy: 0.8000
# Epoch 9/50
# 9/9 [==============================] - 1s 86ms/step - loss: 0.8225 - accuracy: 0.6437 - val_loss: 1.0541 - val_accuracy: 0.8000
# Epoch 10/50
# 9/9 [==============================] - 1s 73ms/step - loss: 0.7705 - accuracy: 0.6437 - val_loss: 1.0305 - val_accuracy: 0.8000
# Epoch 11/50
# 9/9 [==============================] - 1s 77ms/step - loss: 0.7541 - accuracy: 0.6437 - val_loss: 1.0307 - val_accuracy: 0.8000
# Epoch 12/50
# 9/9 [==============================] - 1s 73ms/step - loss: 0.7493 - accuracy: 0.6437 - val_loss: 0.9806 - val_accuracy: 0.8000
# Epoch 13/50
# 9/9 [==============================] - 1s 77ms/step - loss: 0.7383 - accuracy: 0.6437 - val_loss: 1.0623 - val_accuracy: 0.8000
# Epoch 14/50
# 9/9 [==============================] - 1s 70ms/step - loss: 0.7514 - accuracy: 0.6437 - val_loss: 0.9603 - val_accuracy: 0.8000
# Epoch 15/50
# 9/9 [==============================] - 1s 69ms/step - loss: 0.7253 - accuracy: 0.6437 - val_loss: 1.0814 - val_accuracy: 0.8000
# Epoch 16/50
# 9/9 [==============================] - 1s 75ms/step - loss: 0.7178 - accuracy: 0.6590 - val_loss: 1.1244 - val_accuracy: 0.6000
# Epoch 17/50
# 9/9 [==============================] - 1s 71ms/step - loss: 0.7016 - accuracy: 0.6705 - val_loss: 0.9633 - val_accuracy: 0.8000
# Epoch 18/50
# 9/9 [==============================] - 1s 74ms/step - loss: 0.6942 - accuracy: 0.6858 - val_loss: 0.9553 - val_accuracy: 0.8000
# Epoch 19/50
# 9/9 [==============================] - 1s 72ms/step - loss: 0.6942 - accuracy: 0.6782 - val_loss: 0.9542 - val_accuracy: 0.8000
# Epoch 20/50
# 9/9 [==============================] - 1s 80ms/step - loss: 0.7123 - accuracy: 0.6897 - val_loss: 1.0165 - val_accuracy: 0.6000
# Epoch 21/50
# 9/9 [==============================] - 1s 72ms/step - loss: 0.7118 - accuracy: 0.6628 - val_loss: 1.1422 - val_accuracy: 0.4000
# Epoch 22/50
# 9/9 [==============================] - 1s 76ms/step - loss: 0.6890 - accuracy: 0.6858 - val_loss: 0.9156 - val_accuracy: 0.6000
# Epoch 23/50
# 9/9 [==============================] - 1s 71ms/step - loss: 0.6591 - accuracy: 0.6935 - val_loss: 1.2384 - val_accuracy: 0.4000
# Epoch 24/50
# 9/9 [==============================] - 1s 71ms/step - loss: 0.6642 - accuracy: 0.7126 - val_loss: 0.8533 - val_accuracy: 0.6000
# Epoch 25/50
# 9/9 [==============================] - 1s 72ms/step - loss: 0.6416 - accuracy: 0.7126 - val_loss: 0.8868 - val_accuracy: 0.8000
# Epoch 26/50
# 9/9 [==============================] - 1s 71ms/step - loss: 0.6511 - accuracy: 0.6973 - val_loss: 0.8671 - val_accuracy: 0.6000
# Epoch 27/50
# 9/9 [==============================] - 1s 74ms/step - loss: 0.6444 - accuracy: 0.7280 - val_loss: 0.9533 - val_accuracy: 0.6000
# Epoch 28/50
# 9/9 [==============================] - 1s 74ms/step - loss: 0.6262 - accuracy: 0.7088 - val_loss: 0.9904 - val_accuracy: 0.6000
# Epoch 29/50
# 9/9 [==============================] - 1s 76ms/step - loss: 0.6188 - accuracy: 0.7203 - val_loss: 0.7855 - val_accuracy: 0.8000
# Epoch 30/50
# 9/9 [==============================] - 1s 74ms/step - loss: 0.6340 - accuracy: 0.7088 - val_loss: 0.7344 - val_accuracy: 0.6000
# Epoch 31/50
# 9/9 [==============================] - 1s 73ms/step - loss: 0.5980 - accuracy: 0.7203 - val_loss: 1.1352 - val_accuracy: 0.6000
# Epoch 32/50
# 9/9 [==============================] - 1s 69ms/step - loss: 0.5919 - accuracy: 0.7165 - val_loss: 1.3421 - val_accuracy: 0.4000
# Epoch 33/50
# 9/9 [==============================] - 1s 76ms/step - loss: 0.6358 - accuracy: 0.7203 - val_loss: 0.6066 - val_accuracy: 0.6000
# Epoch 34/50
# 9/9 [==============================] - 1s 79ms/step - loss: 0.5946 - accuracy: 0.7548 - val_loss: 0.7358 - val_accuracy: 0.6000
# Epoch 35/50
# 9/9 [==============================] - 1s 73ms/step - loss: 0.5698 - accuracy: 0.7586 - val_loss: 0.8438 - val_accuracy: 0.6000
# Epoch 36/50
# 9/9 [==============================] - 1s 72ms/step - loss: 0.5873 - accuracy: 0.7433 - val_loss: 1.5338 - val_accuracy: 0.4000
# Epoch 37/50
# 9/9 [==============================] - 1s 73ms/step - loss: 0.6297 - accuracy: 0.7203 - val_loss: 0.7041 - val_accuracy: 0.6000
# Epoch 38/50
# 9/9 [==============================] - 1s 75ms/step - loss: 0.5490 - accuracy: 0.7548 - val_loss: 0.6916 - val_accuracy: 0.6000
# Epoch 39/50
# 9/9 [==============================] - 1s 67ms/step - loss: 0.5490 - accuracy: 0.7548 - val_loss: 0.8791 - val_accuracy: 0.4000
# Epoch 40/50
# 9/9 [==============================] - 1s 69ms/step - loss: 0.5346 - accuracy: 0.7510 - val_loss: 0.7796 - val_accuracy: 0.4000
# Epoch 41/50
# 9/9 [==============================] - 1s 73ms/step - loss: 0.5236 - accuracy: 0.7625 - val_loss: 0.4357 - val_accuracy: 0.8000
# Epoch 42/50
# 9/9 [==============================] - 1s 71ms/step - loss: 0.4925 - accuracy: 0.7778 - val_loss: 1.1975 - val_accuracy: 0.4000
# Epoch 43/50
# 9/9 [==============================] - 1s 69ms/step - loss: 0.6026 - accuracy: 0.7548 - val_loss: 1.3383 - val_accuracy: 0.6000
# Epoch 44/50
# 9/9 [==============================] - 1s 73ms/step - loss: 0.6181 - accuracy: 0.7165 - val_loss: 0.6446 - val_accuracy: 0.6000
# Epoch 45/50
# 9/9 [==============================] - 1s 71ms/step - loss: 0.5695 - accuracy: 0.7280 - val_loss: 0.8138 - val_accuracy: 0.6000
# Epoch 46/50
# 9/9 [==============================] - 1s 72ms/step - loss: 0.5221 - accuracy: 0.7586 - val_loss: 0.6421 - val_accuracy: 0.8000
# Epoch 47/50
# 9/9 [==============================] - 1s 69ms/step - loss: 0.4938 - accuracy: 0.7701 - val_loss: 0.5052 - val_accuracy: 0.8000
# Epoch 48/50
# 9/9 [==============================] - 1s 67ms/step - loss: 0.4934 - accuracy: 0.7586 - val_loss: 0.5176 - val_accuracy: 0.6000
# Epoch 49/50
# 9/9 [==============================] - 1s 63ms/step - loss: 0.5329 - accuracy: 0.7395 - val_loss: 0.4957 - val_accuracy: 0.8000
# Epoch 50/50
# 9/9 [==============================] - 1s 65ms/step - loss: 0.4734 - accuracy: 0.7816 - val_loss: 0.3022 - val_accuracy: 0.8000

# %%
def predict(model, img, class_names):
    img_array = tf.keras.preprocessing.image.img_to_array(img)
    img_array = tf.expand_dims(img_array, axis=0)

    predictions = model.predict(img_array)

    predicted_class = class_names[np.argmax(predictions)]
    confidence = round(100 * np.max(predictions), 2)
    return predicted_class, confidence

# %%
import os

# Define the directory containing the dataset
dataset_dir = r'C:\Users\ketha\Downloads\major\bottle dataset'

# Get the class names from the subdirectories in the dataset directory
class_names = sorted(os.listdir(dataset_dir))

print("Class names:", class_names)
# Out:
# Class names: ['Full  Water level', 'Half water level', 'Overflowing']

# %%
class_names: ['Full  Water level', 'Half water level', 'Overflowing']
plt.figure(figsize=(15, 15))
for images, labels in test_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype(np.uint8))

        predicted_class, confidence = predict(model, images[i], class_names)
        actual_class = class_names[labels[i]]

        plt.title(f"Actual: {actual_class}, Predicted: {predicted_class}, Confidence: {confidence}%")
        plt.axis('off')

plt.show()
# Out:
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step

# %%
model.save('CNN.h5')
# Out:
# C:\Users\ketha\anaconda3\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
